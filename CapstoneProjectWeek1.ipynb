# %% [markdown]
# ## The Battle of Neighborhoods (Week 1)
#
# Guangli Ma
#
# Part 1 : Introduction and Data Sections

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_1        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## Coursera Capstone - REPORT CONTENT
# 1.Introduction Section : ⁃ Discussion of the business problem and the interested audience in this project.
#
# 2.Data Section:
#
#  - Description of the data that will be used to solve the problem and the sources.
#
# 3.Methodology section ⁃ Discussion and description of exploratory data analysis carried out, any inferential statistical testing performed, and if any
# machine learnings were used establishing the strategy and purposes.
#
# 4.Results section ⁃ Discussion of the results.
#
# 5.Discussion section ⁃ Elaboration and discussion on any observations noted and any recommendations suggested based on the results.
#
# 6.Conclusion section ⁃ Report Conclusion.

# %% [markdown]
# ## 1. Introduction Section :
#
# ### Discussion of the business problem and the audience who would be interested in this project.
#
# ### Description of the Problem and Background
#
# ### Scenario:
# I am learning the data science rght now and reside in Grand Houston area. I try to compare the business districe in Houston downtown with Manhattan, NY. I am very excited and I want to use this opportunity to practice my learnings in Coursera in order to answer relevant questions arisen. The key question is : How can I find a convenient and enjoyable place similar to mine now in Houston? Certainly, I can also use available real estate apps and Google but the idea is to use and apply myself the learned tools during the course. In order to make a comparison and evaluation of the rental options in Manhattan NY, I want to check the apartment and resturants, therefore the apartment in Manhattan must meet the following demands:
#
# apartment must be 2 or 3 bedrooms
# desired location is near a metro station in the Manhattan area and within 1.0 mile (1.6 km) radius
# price of rent not exceed $7,000 per month
# top ammenities in the selected neighborhood shall be similar to current residence
# desirable to have venues such as coffee shops, restaurants, wine stores, gym and food shops
# as a reference, I have included a map of venues near current residence in Houston.
#
# ## Business Problem:
#
# The challenge is to find a suitable apartment for rent in Manhattan NY that complies with the demands on location, price and venues. The data required to resolve this challenge is described in the following section 2, below.
#
# ## Interested Audience
#
# I believe this is a relevant challenge with valid questions for anyone moving to other large city in US, EU or Asia. The same methodology can be applied in accordance to demands as applicable. This case is also applicable for anyone interested in exploring starting or locating a new business in any city. Lastly, it can also serve as a good practical exercise to develop Data Science skills.

# %% [markdown]
# ## A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# ## 2. Data Section:
# ### Description of the data and its sources that will be used to solve the problem
# ### Description of the Data:
#
# The following data is required to answer the issues of the problem:
#
# List of Boroughs and neighborhoods of Manhattan with their geodata (latitud and longitud)
#
# List of Subway metro stations in Manhattan with their address location
#
# List of apartments for rent in Manhattan area with their addresses and price
#
# Preferably, a list of apartment for rent with additional information, such as price, address, area, # of beds, etc
#
# Venues for each Manhattan neighborhood ( than can be clustered)
#
# Venues for subway metro stations, as needed
#
# ### How the data will be used to solve the problem
# The data will be used as follows:
#
# Use Foursquare and geopy data to map top 10 venues for all Manhattan neighborhoods and clustered in groups ( as per Course LAB)
#
# Use foursquare and geopy data to map the location of subway metro stations , separately and on top of the above clustered map in order to be able to identify the venues and ammenities near each metro station, or explore each subway location separately
#
# Use Foursquare and geopy data to map the location of rental places, in some form, linked to the subway locations.
#
# create a map that depicts, for instance, the average rental price per square ft, around a radious of 1.0 mile (1.6 km) around each subway station - or a similar metrics. I will be able to quickly point to the popups to know the relative price per subway area.
#
# Addresses from rental locations will be converted to geodata( lat, long) using Geopy-distance and Nominatim.
#
# Data will be searched in open data sources if available, from real estate sites if open to reading, libraries or other government agencies such as Metro New York MTA, etc.
#
# The procesing of these DATA will allow to answer the key questions to make a decision:
#
# what is the cost of rent (per square ft) around a mile radius from each subway metro station?
#
# what is the area of Manhattan with best rental pricing that meets criteria established?
#
# What is the distance from work place ( Park Ave and 53 rd St) and the tentative future home?
#
# What are the venues of the two best places to live? How the prices compare?
#
# How venues distribute among Manhattan neighborhoods and around metro stations?
#
# Are there tradeoffs between size and price and location?
#
# Any other interesting statistical data findings of the real estate and overall data.
#
# ### Reference of venues around current residence in Singapore for comparison to Manhattan place

# %%
# houston central business district, Houston, Texas
address = 'Mckinney street,houston, Texas'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Houston central business district are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# The geograpical coordinate of Houston central business district are 29.7515381, -95.3560473.

# %%
neighborhood_latitude=29.7515381
neighborhood_longitude=-95.3560473

# %%
### Define Foursquare Credentials and Version
CLIENT_ID = 'EUDO0LACN3MV3DFIHGMVUMSWAILSHCBAOUVYP5EOGLXYTXTY'
CLIENT_SECRET = '41LFAJPS4WAQATSRKHGKOBPZRZBCUKB0TMWTR0VAJCIJJ3SD'
VERSION = '20180605'

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=EUDO0LACN3MV3DFIHGMVUMSWAILSHCBAOUVYP5EOGLXYTXTY&client_secret=41LFAJPS4WAQATSRKHGKOBPZRZBCUKB0TMWTR0VAJCIJJ3SD&v=20180605&ll=29.7515381,-95.3560473&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f2d4f06e48ac773fa7d3084'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Downtown Houston',
#   'headerFullLocation': 'Downtown Houston, Houston',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 65,
#   'suggestedBounds': {'ne': {'lat': 29.756038104500007,
#     'lng': -95.35087374836685},
#    'sw': {'lat': 29.747038095499995, 'lng': -95.36122085163315}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aea1af39e0d54002cf8ea56',
#        'name': 'Truck Yard',
#        'location': {'address': '2118 Lamar St',
#         'crossStreet': 'btwn St Emanuel & Hutchins',
#         'lat': 29.74971787706592,
#         'lng': -95.35597818492893,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.74971787706592,
#           'lng': -95.35597818492893},
#          {'label': 'entrance', 'lat': 29.750257, 'lng': -95.355872}],
#         'distance': 202,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2118 Lamar St (btwn St Emanuel & Hutchins)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '543579098'}},
#       'referralId': 'e-0-5aea1af39e0d54002cf8ea56-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b42a9dcf964a5206fd825e3',
#        'name': 'Huynh Restaurant',
#        'location': {'address': '912 St Emanuel St',
#         'lat': 29.75169152493912,
#         'lng': -95.35532092486456,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75169152493912,
#           'lng': -95.35532092486456}],
#         'distance': 72,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['912 St Emanuel St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b42a9dcf964a5206fd825e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5815e67c38facd634a94a44f',
#        'name': "Pappadeaux's Seafood Kitchen",
#        'location': {'address': '1001 Avenida de las Americas',
#         'lat': 29.7524809,
#         'lng': -95.35789229999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7524809,
#           'lng': -95.35789229999999}],
#         'distance': 206,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1001 Avenida de las Americas',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d17a941735',
#          'name': 'Cajun / Creole Restaurant',
#          'pluralName': 'Cajun / Creole Restaurants',
#          'shortName': 'Cajun / Creole',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5815e67c38facd634a94a44f-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ae7aac7031320002c957f39',
#        'name': 'Pitch 25 Beer Park',
#        'location': {'address': '2120 Walker St',
#         'lat': 29.75168775951742,
#         'lng': -95.35466790845334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75168775951742,
#           'lng': -95.35466790845334}],
#         'distance': 134,
#         'postalCode': '77003',
#         'cc': 'US',
#         'neighborhood': 'Downtown Houston',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2120 Walker St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1915509',
#         'url': 'https://www.grubhub.com/restaurant/pitch-25-beer-park-2120-walker-street-houston/1915509?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1915509',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '512019719'}},
#       'referralId': 'e-0-5ae7aac7031320002c957f39-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ab9674086bc496f369c1d2f',
#        'name': 'Rodeo Goat',
#        'location': {'address': 'St. Emmanuel',
#         'crossStreet': 'Dallas',
#         'lat': 29.749972711174166,
#         'lng': -95.3563011432822,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.749972711174166,
#           'lng': -95.3563011432822}],
#         'distance': 175,
#         'postalCode': '77003',
#         'cc': 'US',
#         'neighborhood': 'Downtown Houston',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['St. Emmanuel (Dallas)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1917234',
#         'url': 'https://www.grubhub.com/restaurant/rodeo-goat-2118-lamar-street-houston/1917234?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1917234',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ab9674086bc496f369c1d2f-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58f00d07829b0c25eb9bd11d',
#        'name': 'Chapman & Kirby',
#        'location': {'address': '2118 Lamar St',
#         'lat': 29.750338909744485,
#         'lng': -95.35600169403479,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.750338909744485,
#           'lng': -95.35600169403479}],
#         'distance': 133,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2118 Lamar St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1575724',
#         'url': 'https://www.grubhub.com/restaurant/chapman--kirby-2118-lamar-street-houston/1575724?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1575724',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58f00d07829b0c25eb9bd11d-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59073b0a35811b1afa0f9ef1',
#        'name': 'SeaSide Poke',
#        'location': {'address': '2118 Lamar St',
#         'lat': 29.750250510123283,
#         'lng': -95.35623516350616,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.750250510123283,
#           'lng': -95.35623516350616}],
#         'distance': 144,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2118 Lamar St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79fe',
#          'name': 'Hawaiian Restaurant',
#          'pluralName': 'Hawaiian Restaurants',
#          'shortName': 'Hawaiian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '977392',
#         'url': 'https://www.grubhub.com/restaurant/seaside-poke-2118-lamar-st-ste-101-houston/977392?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=977392',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59073b0a35811b1afa0f9ef1-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5320d0b9498edcd270d2fd25',
#        'name': "Neil's Bahr",
#        'location': {'address': '2006 Walker St',
#         'crossStreet': 'Eastex Fwy',
#         'lat': 29.75223506951304,
#         'lng': -95.35545629868716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75223506951304,
#           'lng': -95.35545629868716}],
#         'distance': 96,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2006 Walker St (Eastex Fwy)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5320d0b9498edcd270d2fd25-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5334a784498e069542cf3201',
#        'name': "Sticky's Chicken",
#        'location': {'address': 'Moving Target! (Greater Houston Area)',
#         'lat': 29.752723621666096,
#         'lng': -95.35470598971514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752723621666096,
#           'lng': -95.35470598971514}],
#         'distance': 184,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Moving Target! (Greater Houston Area)',
#          'Houston, TX',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5334a784498e069542cf3201-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561579dc498e1a47b5a64962',
#        'name': "King's Court Bar and Kitchen",
#        'location': {'address': '903 Hutchins St',
#         'lat': 29.751209,
#         'lng': -95.35396,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.751209,
#           'lng': -95.35396},
#          {'label': 'entrance', 'lat': 29.751059, 'lng': -95.354248}],
#         'distance': 205,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['903 Hutchins St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-561579dc498e1a47b5a64962-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '444999c5f964a52076321fe3',
#        'name': 'Warehouse Live',
#        'location': {'address': '813 St Emanuel St',
#         'crossStreet': 'Rusk St',
#         'lat': 29.752059933334234,
#         'lng': -95.35458526365262,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752059933334234,
#           'lng': -95.35458526365262}],
#         'distance': 152,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['813 St Emanuel St (Rusk St)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '69888109'}},
#       'referralId': 'e-0-444999c5f964a52076321fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bef50142f97ec002c3d9bd7',
#        'name': 'Miss Carousel',
#        'location': {'address': '1201 St. Emanuel',
#         'crossStreet': 'Dallas',
#         'lat': 29.74936844075125,
#         'lng': -95.35658529185409,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.74936844075125,
#           'lng': -95.35658529185409}],
#         'distance': 247,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1201 St. Emanuel (Dallas)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bef50142f97ec002c3d9bd7-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eace8af8b8181aef7e49f44',
#        'name': '8th Wonder Brewery',
#        'location': {'address': '2202 Dallas St',
#         'lat': 29.748620833774513,
#         'lng': -95.35595930605157,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.748620833774513,
#           'lng': -95.35595930605157}],
#         'distance': 324,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2202 Dallas St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eace8af8b8181aef7e49f44-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bacc989f964a520410c3be3',
#        'name': 'Comicpalooza Convention',
#        'location': {'address': '1001 Avenida de Las Americas',
#         'crossStreet': 'Lamar',
#         'lat': 29.75245337684057,
#         'lng': -95.35916135052251,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75245337684057,
#           'lng': -95.35916135052251}],
#         'distance': 317,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1001 Avenida de Las Americas (Lamar)',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b18',
#          'name': 'Comic Shop',
#          'pluralName': 'Comic Shops',
#          'shortName': 'Comic Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/comic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bacc989f964a520410c3be3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4dabfeb1fa236ab0359129',
#        'name': 'BBVA Compass Stadium',
#        'location': {'address': '2200 Texas St',
#         'crossStreet': 'at Dowling St.',
#         'lat': 29.75266593666373,
#         'lng': -95.35254485495663,
#         'distance': 361,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2200 Texas St (at Dowling St.)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d188941735',
#          'name': 'Soccer Stadium',
#          'pluralName': 'Soccer Stadiums',
#          'shortName': 'Soccer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37907315'}},
#       'referralId': 'e-0-4d4dabfeb1fa236ab0359129-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5347fdfb11d2a904ff2a7a6e',
#        'name': 'Marriott Marquis Houston',
#        'location': {'address': '1777 Walker Street',
#         'crossStreet': 'Avenida De Las Americas',
#         'lat': 29.7544464,
#         'lng': -95.3581201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7544464,
#           'lng': -95.3581201}],
#         'distance': 380,
#         'postalCode': '77010',
#         'cc': 'US',
#         'neighborhood': 'Downtown Houston',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1777 Walker Street (Avenida De Las Americas)',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1575464',
#         'url': 'https://www.grubhub.com/restaurant/walker-street-kitchen-houston-marriott-marquis-1777-walker-street-houston/1575464?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1575464',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '153917436'}},
#       'referralId': 'e-0-5347fdfb11d2a904ff2a7a6e-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac6e1b1f964a52084b620e3',
#        'name': 'Discovery Green',
#        'location': {'address': '1500 McKinney St',
#         'crossStreet': 'at Avenida de las Americas',
#         'lat': 29.753237897872424,
#         'lng': -95.35948276519775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.753237897872424,
#           'lng': -95.35948276519775}],
#         'distance': 382,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1500 McKinney St (at Avenida de las Americas)',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac6e1b1f964a52084b620e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c6df8d735f983002c04e6f1',
#        'name': 'True Anomaly Brewing Company',
#        'location': {'address': '2012 Dallas St',
#         'crossStreet': 'at St Emanuel St',
#         'lat': 29.74968436768098,
#         'lng': -95.35710632801056,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.74968436768098,
#           'lng': -95.35710632801056}],
#         'distance': 230,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2012 Dallas St (at St Emanuel St)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c6df8d735f983002c04e6f1-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5815e4be38fab8bf7b564739',
#        'name': 'Grotto Downtown',
#        'location': {'address': '1001 Avenida de las Americas Ste A',
#         'lat': 29.7539178,
#         'lng': -95.3571966,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7539178,
#           'lng': -95.3571966}],
#         'distance': 287,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1001 Avenida de las Americas Ste A',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2046170',
#         'url': 'https://www.grubhub.com/restaurant/grotto-ristorante-1001-avenida-de-las-americas-houston/2046170?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2046170',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5815e4be38fab8bf7b564739-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '552d1bf3498e45c3958b3873',
#        'name': 'AHH Coffee!',
#        'location': {'address': '2018 Rusk St',
#         'lat': 29.752803861789086,
#         'lng': -95.35481322514916,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752803861789086,
#           'lng': -95.35481322514916},
#          {'label': 'entrance', 'lat': 29.75271, 'lng': -95.354797}],
#         'distance': 184,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2018 Rusk St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1913482',
#         'url': 'https://www.grubhub.com/restaurant/ahh-coffee-2018-rusk-street-houston/1913482?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1913482',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-552d1bf3498e45c3958b3873-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1473ccf964a5204fa323e3',
#        'name': "Lucky's Pub",
#        'location': {'address': '801 St Emanuel St',
#         'lat': 29.752459211963238,
#         'lng': -95.35413132402206,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752459211963238,
#           'lng': -95.35413132402206}],
#         'distance': 211,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['801 St Emanuel St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1575906',
#         'url': 'https://www.grubhub.com/restaurant/luckys-pub-801-saint-emanuel-street-houston/1575906?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1575906',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1473ccf964a5204fa323e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bea335351950e002c48b100',
#        'name': 'Indianola',
#        'location': {'address': '1201 St Emanuel St',
#         'lat': 29.74946870636263,
#         'lng': -95.35670754486358,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.74946870636263,
#           'lng': -95.35670754486358}],
#         'distance': 239,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1201 St Emanuel St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bea335351950e002c48b100-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d335cd6eefa8cfa544d40b3',
#        'name': "Little Woodrow's",
#        'location': {'address': '2019 Walker St',
#         'crossStreet': 'at St. Emanuel St.',
#         'lat': 29.752275549125823,
#         'lng': -95.35484478551584,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752275549125823,
#           'lng': -95.35484478551584},
#          {'label': 'entrance', 'lat': 29.752159, 'lng': -95.354934}],
#         'distance': 142,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2019 Walker St (at St. Emanuel St.)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d335cd6eefa8cfa544d40b3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56f63cba498ee61de522706c',
#        'name': 'The Secret Group',
#        'location': {'lat': 29.749085644243934,
#         'lng': -95.35717882135917,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.749085644243934,
#           'lng': -95.35717882135917},
#          {'label': 'entrance', 'lat': 29.748944, 'lng': -95.356918}],
#         'distance': 294,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56f63cba498ee61de522706c-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b156839f964a52066ac23e3',
#        'name': 'Hilton',
#        'location': {'address': '1600 Lamar St',
#         'crossStreet': 'at Crawford St',
#         'lat': 29.7514414,
#         'lng': -95.3605728,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7514414,
#           'lng': -95.3605728}],
#         'distance': 437,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1600 Lamar St (at Crawford St)',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b156839f964a52066ac23e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4beeef38d355a5937a940b60',
#        'name': 'Long Sing Supermarket',
#        'location': {'address': '815 Chartres St',
#         'lat': 29.752373,
#         'lng': -95.355009,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752373,
#           'lng': -95.355009},
#          {'label': 'entrance', 'lat': 29.752282, 'lng': -95.355081}],
#         'distance': 136,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['815 Chartres St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4beeef38d355a5937a940b60-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae106ebf964a520b48421e3',
#        'name': 'The Grove',
#        'location': {'address': '1611 Lamar St',
#         'crossStreet': 'Dallas',
#         'lat': 29.752581423767637,
#         'lng': -95.36053197196186,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752581423767637,
#           'lng': -95.36053197196186}],
#         'distance': 448,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1611 Lamar St (Dallas)',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2285553',
#         'url': 'https://www.grubhub.com/restaurant/the-grove-1611-lamar-st-houston/2285553?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2285553',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '45979502'}},
#       'referralId': 'e-0-4ae106ebf964a520b48421e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5814b48d38fa91a230b3085d',
#        'name': "Biggio's",
#        'location': {'address': '1777 Walker St',
#         'lat': 29.754688,
#         'lng': -95.358142,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.754688,
#           'lng': -95.358142}],
#         'distance': 404,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1777 Walker St',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5814b48d38fa91a230b3085d-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '504937d7e4b0f3a8fa5b823f',
#        'name': 'Dynamo Private Beer Garden',
#        'location': {'lat': 29.752425463502842,
#         'lng': -95.35378209050933,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752425463502842,
#           'lng': -95.35378209050933}],
#         'distance': 240,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77003', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-504937d7e4b0f3a8fa5b823f-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52ab9bdb11d2fb444a0d1cd2',
#        'name': 'Hilton Americas Executive Lounge',
#        'location': {'lat': 29.75204261893564,
#         'lng': -95.36078282398125,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75204261893564,
#           'lng': -95.36078282398125}],
#         'distance': 461,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52ab9bdb11d2fb444a0d1cd2-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bd73b7d4c954c002c06229b',
#        'name': 'The Rustic',
#        'location': {'lat': 29.75017459873822,
#         'lng': -95.35963598381504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75017459873822,
#           'lng': -95.35963598381504}],
#         'distance': 378,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77003', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bd73b7d4c954c002c06229b-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ac51ed498ece561de831aa',
#        'name': 'Xochi',
#        'location': {'address': '1777 Walker St Ste A',
#         'lat': 29.754480182176135,
#         'lng': -95.35908860025862,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.754480182176135,
#           'lng': -95.35908860025862},
#          {'label': 'entrance', 'lat': 29.754079, 'lng': -95.357744}],
#         'distance': 440,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1777 Walker St Ste A',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ac51ed498ece561de831aa-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5595e03a498e87852be8f16f',
#        'name': 'Be Fit Gym',
#        'location': {'address': '2420 Rusk St',
#         'crossStreet': 'St. Charles',
#         'lat': 29.75067686339788,
#         'lng': -95.35108396663715,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75067686339788,
#           'lng': -95.35108396663715},
#          {'label': 'entrance', 'lat': 29.750813, 'lng': -95.351314}],
#         'distance': 489,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2420 Rusk St (St. Charles)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5595e03a498e87852be8f16f-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5ebf956ebe2d7f6e5ad62e',
#        'name': 'Pool Teracce @ Hilton Americas',
#        'location': {'address': '1600 Lamar St',
#         'lat': 29.75164953216348,
#         'lng': -95.36115063724893,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75164953216348,
#           'lng': -95.36115063724893}],
#         'distance': 493,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1600 Lamar St',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5ebf956ebe2d7f6e5ad62e-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa536c8e4b094b94622624b',
#        'name': 'Houston Dynamo Team Store',
#        'location': {'lat': 29.752564989104805,
#         'lng': -95.35213613881542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752564989104805,
#           'lng': -95.35213613881542}],
#         'distance': 394,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77003', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fa536c8e4b094b94622624b-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfbd51fc6cca35da06a8e32',
#        'name': 'The Ice at Discovery Green',
#        'location': {'lat': 29.753700987318382,
#         'lng': -95.3595445685004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.753700987318382,
#           'lng': -95.3595445685004}],
#         'distance': 414,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77010', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfbd51fc6cca35da06a8e32-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
# ...
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['George R. Brown',
#          'Houston, TX',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b1f',
#          'name': 'Shipping Store',
#          'pluralName': 'Shipping Stores',
#          'shortName': 'Shipping Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-517a9f23e4b0ea244ef0baaa-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d811f4be6d7721e802725c7',
#        'name': 'FedEx Office Print & Ship Center',
#        'location': {'address': '1001 Avenida De Las Americas',
#         'lat': 29.7515262,
#         'lng': -95.3590284,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7515262,
#           'lng': -95.3590284}],
#         'distance': 288,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1001 Avenida De Las Americas',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b1f',
#          'name': 'Shipping Store',
#          'pluralName': 'Shipping Stores',
#          'shortName': 'Shipping Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d811f4be6d7721e802725c7-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6683b905a7f04d446ab38f',
#        'name': 'Starbucks',
#        'location': {'address': '1600 Lamar St',
#         'lat': 29.751496,
#         'lng': -95.360234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.751496,
#           'lng': -95.360234}],
#         'distance': 404,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1600 Lamar St',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6683b905a7f04d446ab38f-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b106c98f964a520257023e3',
#        'name': 'The Lake House',
#        'location': {'address': '1600 McKinney St',
#         'lat': 29.753505227121686,
#         'lng': -95.35956500686406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.753505227121686,
#           'lng': -95.35956500686406},
#          {'label': 'entrance', 'lat': 29.753574, 'lng': -95.359667}],
#         'distance': 404,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1600 McKinney St',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1565450',
#         'url': 'https://www.grubhub.com/restaurant/the-lake-house-waterside-cafe-1600-mckinney-street-houston/1565450?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1565450',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b106c98f964a520257023e3-54'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5815db0538fa02bb536b00f0',
#        'name': 'Kulture',
#        'location': {'address': '701 Avenida de las Americas Ste A',
#         'lat': 29.75482564933337,
#         'lng': -95.35710223619611,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75482564933337,
#           'lng': -95.35710223619611}],
#         'distance': 379,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['701 Avenida de las Americas Ste A',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5815db0538fa02bb536b00f0-55'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57118b87498e6ad5293af19d',
#        'name': 'HTX Fan Tavern',
#        'location': {'lat': 29.755436050370935,
#         'lng': -95.35535574506187,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.755436050370935,
#           'lng': -95.35535574506187}],
#         'distance': 439,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57118b87498e6ad5293af19d-56'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fcbb9f498e7a8fbb525e6d',
#        'name': 'Super K Food Mart',
#        'location': {'lat': 29.75173159095204,
#         'lng': -95.35525778178294,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75173159095204,
#           'lng': -95.35525778178294}],
#         'distance': 79,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55fcbb9f498e7a8fbb525e6d-57'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da906f9a86e771ea70212f1',
#        'name': "Pearl's & Johnny B's BBQ",
#        'location': {'address': '1005 Emmanuel St. Ste 11',
#         'crossStreet': 'Lamar St',
#         'lat': 29.752043137985815,
#         'lng': -95.35434834952845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.752043137985815,
#           'lng': -95.35434834952845}],
#         'distance': 173,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1005 Emmanuel St. Ste 11 (Lamar St)',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da906f9a86e771ea70212f1-58'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb5044be4b0243a5ef53c20',
#        'name': 'Lofts at the ballpark Internet Cafe',
#        'location': {'lat': 29.75406753727727,
#         'lng': -95.3535819851692,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75406753727727,
#           'lng': -95.3535819851692}],
#         'distance': 368,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77003', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fb5044be4b0243a5ef53c20-59'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57084414498e4c3d45dc5fb4',
#        'name': 'TB3HOME',
#        'location': {'lat': 29.748411,
#         'lng': -95.354499,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.748411,
#           'lng': -95.354499}],
#         'distance': 378,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77003', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57084414498e4c3d45dc5fb4-60'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '557eb210498eee5427638f34',
#        'name': 'METRORail Convention Center Capitol Station',
#        'location': {'address': 'Capitol St & Chenevert St',
#         'lat': 29.755060574520858,
#         'lng': -95.35554900750296,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.755060574520858,
#           'lng': -95.35554900750296}],
#         'distance': 395,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Capitol St & Chenevert St',
#          'Houston, TX',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-557eb210498eee5427638f34-61'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53d9b862498e20e413f561ae',
#        'name': 'Eado/Stadium Light Rail Station',
#        'location': {'lat': 29.75354271666723,
#         'lng': -95.35205439593487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75354271666723,
#           'lng': -95.35205439593487}],
#         'distance': 445,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53d9b862498e20e413f561ae-62'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55831176498e34732b181d51',
#        'name': 'METRORail EaDo/Stadium Station',
#        'location': {'address': 'Texas Ave & Bastrop St',
#         'lat': 29.753505591659874,
#         'lng': -95.35201585109134,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.753505591659874,
#           'lng': -95.35201585109134}],
#         'distance': 446,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Texas Ave & Bastrop St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55831176498e34732b181d51-63'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf8750f4a67c928337c25cf',
#        'name': 'Astrosbaseballfan.com',
#        'location': {'lat': 29.75599479886512,
#         'lng': -95.35579425135528,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75599479886512,
#           'lng': -95.35579425135528}],
#         'distance': 496,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77002', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf8750f4a67c928337c25cf-64'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
SGnearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]

# filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)

# clean columns
SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.head(10)
# Out:
#                            name                 categories        lat  \
# 0                    Truck Yard                   Beer Bar  29.749718
# 1              Huynh Restaurant      Vietnamese Restaurant  29.751692
# 2  Pappadeaux's Seafood Kitchen  Cajun / Creole Restaurant  29.752481
# 3            Pitch 25 Beer Park                        Bar  29.751688
# 4                    Rodeo Goat               Burger Joint  29.749973
# 5               Chapman & Kirby                        Bar  29.750339
# 6                  SeaSide Poke        Hawaiian Restaurant  29.750251
# 7                   Neil's Bahr                Beer Garden  29.752235
# 8              Sticky's Chicken                 Food Truck  29.752724
# 9  King's Court Bar and Kitchen          Indian Restaurant  29.751209
#
#          lng
# 0 -95.355978
# 1 -95.355321
# 2 -95.357892
# 3 -95.354668
# 4 -95.356301
# 5 -95.356002
# 6 -95.356235
# 7 -95.355456
# 8 -95.354706
# 9 -95.353960

# %% [markdown]
# ## Map of Houston with venues near residence place - for reference

# %%
# create map of Singapore place  using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=20)

# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=4,
        radius=10,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.7,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
